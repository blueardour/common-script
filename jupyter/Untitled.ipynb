# %%
import numpy as np

# %%
sobel_kernel = np.array([[-1, -1, -1], [-1, 8, -1], [-1, -1, -1]], dtype='float32')

# %%
#sobel_kernel, sobel_kernel.shape

# %%
sobel_kernel = sobel_kernel.reshape((1, 1, 3, 3))

# %%
sobel_kernel = np.repeat(sobel_kernel, 3, axis=1)

# %%
sobel_kernel = np.repeat(sobel_kernel, 3, axis=0)

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import sys, os
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 200
import torch

# %%
img = cv2.imread('/home/chenp/Documents/1.jpg')

# %%
img2 = img[:,:,::-1]
plt.imshow(img2)

# %%
filters = torch.nn.Conv2d(3, 3, kernel_size=3, padding=1, groups=1, bias=False,)
#filters.weight.data = torch.from_numpy(sobel_kernel)
print(filters)
# Out:
# Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)

# %%
img_t2 = img2.transpose(2, 0, 1)
print(img_t2.shape)
img_t2 = torch.from_numpy(img_t2.copy())
print(img_t2.shape)
# Out:
# (3, 500, 371)
# torch.Size([3, 500, 371])

# %%
img_t2 = img_t2.unsqueeze(0)
print(img_t2.shape)
# Out:
# torch.Size([1, 3, 500, 371])

# %%
img_t3 = filters(img_t2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-41-4e118f218dd2> in <module>
# ----> 1 img_t3 = filters(img_t2)
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     417
#     418     def forward(self, input: Tensor) -> Tensor:
# --> 419         return self._conv_forward(input, self.weight)
#     420
#     421 class Conv3d(_ConvNd):
#
# ...
